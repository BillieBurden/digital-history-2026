# %% [markdown]
# <a href="https://colab.research.google.com/github/BillieBurden/digital-history-2026/blob/main/Boarding_Cleanser_Script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive

drive.mount('drive')
file_path = ('drive/MyDrive/Colab Notebooks/schools.csv')

df = pd.read_csv(file_path)
df.head()
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).
#                                       School  \
# 0             Chemawa Indian Training School
# 1          Carlisle Indian Industrial School
# 2  Haskell Indian Industrial Training School
# 3                  Fort Hall Boarding School
# 4           Sherman Institute: Riverside, CA
#
#                                             School.1 State  join_id  \
# 0  [Chemawa Indian Training School](https://githu...    OR      352
# 1  [Carlisle Indian Industrial School](https://gi...    PA      360
# 2  [Haskell Indian Industrial Training School](ht...    KS      128
# 3  [Fort Hall Boarding School](https://github.com...    ID      110
# 4  [Sherman Institute](https://github.com/washing...    CA       78
#
#   operation_dates religions_identified  \
# 0     1880 - Open                  NaN
# 1     1879 - 1918                  NaN
# 2     1884 - Open                  NaN
# ...

# %%
df.isnull().sum()
# Out:
# School                    0
# School.1                  0
# State                     0
# join_id                   0
# operation_dates           7
# religions_identified    208
# tribes_identified         0
# DOI deceased              0
# WP deceased               0
# DOI burial sites        353
# WP burial sites         361
# other_names              56
# Latitude                 14
# Longitude                14
# Verified                 14
# dtype: int64

# %%
df.drop(columns= ['religions_identified', 'School.1'])
# Out:
#                                               School State  join_id  \
# 0                     Chemawa Indian Training School    OR      352
# 1                  Carlisle Indian Industrial School    PA      360
# 2          Haskell Indian Industrial Training School    KS      128
# 3                          Fort Hall Boarding School    ID      110
# 4                   Sherman Institute: Riverside, CA    CA       78
# ..                                               ...   ...      ...
# 413                St. Michael's Manual Labor School    ND      258
# 414  C. L. Halls' Congregational Mission Home School    ND      260
# 415                         Cherokee Female Seminary    AZ      277
# 416                      Sacred Heart Mission School    OK      296
# 417          Klamath Agency / Yainax Boarding School    OR      351
#
#                operation_dates  \
# 0                  1880 - Open
# 1                  1879 - 1918
# 2                  1884 - Open
# ...
